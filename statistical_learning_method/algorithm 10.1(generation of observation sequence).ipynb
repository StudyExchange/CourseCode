# %% [markdown]
# # 算法 10.1（观测序列的生成）
# - 使用p175，10.2.1 直接计算法
# - 测试数据1：测试数据：p177，例10.2（主要的测试数据）
# - 测试数据2：测试数据：p173，例10.1（盒子和球模型）（用来与前向和后向算法做对照可以相互印证，结果是否正确。另外，由于p177，例10.2中，a的状态的数量、b的状态的数量和观测序列的长度是对齐的，都是3，难以辨别对应的参数是否用对了，所以p173，例10.1没有对齐的数据可以用来检验一下。）
# - 测试结果1：与书中结果一致：0.13018四舍五入为0.13022

# %%
import math

class MarkovForward(object):
    def probability(self, a, b, pi, output):
        an = len(a[0]) # a的状态的数量
        bn = len(b[0]) # b的状态的数量
        m = len(output) # 观测序列的长度
        inputs = []
        total_count = int(math.pow(an, m))
        result = 0
        for i in range(total_count): # i表示总的循环数
            # for j in range(an): # j表示pi的index
                # index_li = [j]
            index_li = MarkovForward.get_sequence_index(i, an, m)
            print('q_t的集合：%s' % index_li, end='。') # 即本次循环的状态集合，即本次循环的选中的盒子的集合
            prob = pi[index_li[0]] # pi(i1)
            for k in range(m - 1):
                prob *= b[index_li[k]][output[k]] # b_i1(o1), b_i2(o2)
                print('i%s->i%s' % (k, k+1), end='  ')
                prob *= a[index_li[k]][index_li[k+1]] # a_i1_i2, a_i2_i3
            prob *= b[index_li[m - 1]][output[m - 1]] # b_i3(o3)
            print('  %.5f' % prob)
            result += prob
        return result


    @staticmethod
    def get_sequence_index(num, an, m):
        if num:
            index_li = []
            while num:
                quotient, remainder = divmod(num, an)
                num = quotient
                index_li.append(remainder)
            if len(index_li) < m:
                index_li.extend([0]*(m - len(index_li)))
            return index_li
        else:
            return [0]*m

    def is_skip(self, indexes):
        pass

# %%
# 测试数据1：测试数据：p177，例10.2（主要的测试数据）
a = [
    [0.5, 0.2, 0.3],
    [0.3, 0.5, 0.2],
    [0.2, 0.3, 0.5]
]
b = [
    [0.5, 0.5],
    [0.4, 0.6],
    [0.7, 0.3]
]
pi = [0.2, 0.4, 0.4]
output = [0, 1, 0]

mf = MarkovForward()
print(mf.probability(a, b, pi, output))
# Out:
# q_t的集合：[0, 0, 0]。i0->i1  i1->i2    0.00625
# q_t的集合：[1, 0, 0]。i0->i1  i1->i2    0.00600
# q_t的集合：[2, 0, 0]。i0->i1  i1->i2    0.00700
# q_t的集合：[0, 1, 0]。i0->i1  i1->i2    0.00180
# q_t的集合：[1, 1, 0]。i0->i1  i1->i2    0.00720
# q_t的集合：[2, 1, 0]。i0->i1  i1->i2    0.00756
# q_t的集合：[0, 2, 0]。i0->i1  i1->i2    0.00090
# q_t的集合：[1, 2, 0]。i0->i1  i1->i2    0.00096
# q_t的集合：[2, 2, 0]。i0->i1  i1->i2    0.00420
# q_t的集合：[0, 0, 1]。i0->i1  i1->i2    0.00200
# q_t的集合：[1, 0, 1]。i0->i1  i1->i2    0.00192
# q_t的集合：[2, 0, 1]。i0->i1  i1->i2    0.00224
# q_t的集合：[0, 1, 1]。i0->i1  i1->i2    0.00240
# q_t的集合：[1, 1, 1]。i0->i1  i1->i2    0.00960
# q_t的集合：[2, 1, 1]。i0->i1  i1->i2    0.01008
# q_t的集合：[0, 2, 1]。i0->i1  i1->i2    0.00108
# q_t的集合：[1, 2, 1]。i0->i1  i1->i2    0.00115
# q_t的集合：[2, 2, 1]。i0->i1  i1->i2    0.00504
# q_t的集合：[0, 0, 2]。i0->i1  i1->i2    0.00525
# q_t的集合：[1, 0, 2]。i0->i1  i1->i2    0.00504
# q_t的集合：[2, 0, 2]。i0->i1  i1->i2    0.00588
# q_t的集合：[0, 1, 2]。i0->i1  i1->i2    0.00168
# q_t的集合：[1, 1, 2]。i0->i1  i1->i2    0.00672
# q_t的集合：[2, 1, 2]。i0->i1  i1->i2    0.00706
# q_t的集合：[0, 2, 2]。i0->i1  i1->i2    0.00315
# q_t的集合：[1, 2, 2]。i0->i1  i1->i2    0.00336
# q_t的集合：[2, 2, 2]。i0->i1  i1->i2    0.01470
# 0.130218

# %%
# 测试数据2：测试数据：p173，例10.1（盒子和球模型）（用来与前向和后向算法做对照可以相互印证，结果是否正确）
a = [
    [0, 1, 0, 0],
    [0.4, 0, 0.6, 0],
    [0, 0.4, 0, 0.6],
    [0, 0, 0.5, 0.5]
]
b = [
    [0.5, 0.5],
    [0.3, 0.7],
    [0.6, 0.4],
    [0.8, 0.2]
]
pi = (0.25, 0.25, 0.25, 0.25)
output = [0, 0, 1, 1, 0]

mf = MarkovForward()
print(mf.probability(a, b, pi, output))
# Out:
# q_t的集合：[0, 0, 0, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 0, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 0, 0, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 0, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 0, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 1, 0, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 0, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 1, 0, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 0, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 0, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 2, 0, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 0, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 3, 0, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 0, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 0, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 3, 0, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 0, 1, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 1, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 0, 1, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 1, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 1, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 1, 1, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 1, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 1, 1, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 1, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 1, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 2, 1, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 1, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 3, 1, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 1, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 1, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 3, 1, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 0, 2, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 2, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 0, 2, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 2, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 2, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 1, 2, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 2, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 1, 2, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 2, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 2, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 2, 2, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 2, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 3, 2, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 2, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 2, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 3, 2, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 0, 3, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 3, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 0, 3, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 3, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 3, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 1, 3, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 3, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 1, 3, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 3, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 3, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 2, 3, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 3, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 3, 3, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 3, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 3, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 3, 3, 0, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 0, 0, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 0, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 0, 0, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 0, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 0, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00105
# q_t的集合：[1, 1, 0, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 0, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00050
# q_t的集合：[3, 1, 0, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 0, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 0, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 2, 0, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 0, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 3, 0, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 0, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 0, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 3, 0, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 0, 1, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 1, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 0, 1, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 1, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 1, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 1, 1, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 1, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 1, 1, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 1, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 1, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 2, 1, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 1, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 3, 1, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 1, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 1, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 3, 1, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 0, 2, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 2, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 0, 2, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 2, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 2, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00050
# q_t的集合：[1, 1, 2, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 2, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00024
# q_t的集合：[3, 1, 2, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 2, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 2, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 2, 2, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 2, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 3, 2, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 2, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 2, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00081
# q_t的集合：[3, 3, 2, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00090
# q_t的集合：[0, 0, 3, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 3, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 0, 3, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 3, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 3, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 1, 3, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 3, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 1, 3, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 3, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 3, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 2, 3, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 3, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 3, 3, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 3, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 3, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 3, 3, 1, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 0, 0, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 0, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 0, 0, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 0, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 0, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 1, 0, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 0, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 1, 0, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 0, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 0, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 2, 0, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 0, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 3, 0, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 0, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 0, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 3, 0, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 0, 1, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 1, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 0, 1, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 1, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 1, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 1, 1, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 1, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 1, 1, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 1, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 1, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 2, 1, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 1, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 3, 1, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 1, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 1, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 3, 1, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 0, 2, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 2, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 0, 2, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 2, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 2, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 1, 2, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 2, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 1, 2, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 2, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 2, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 2, 2, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 2, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 3, 2, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 2, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 2, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 3, 2, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 0, 3, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 3, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 0, 3, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 3, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 3, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 1, 3, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 3, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 1, 3, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 3, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 3, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 2, 3, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 3, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 3, 3, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 3, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 3, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 3, 3, 2, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 0, 0, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 0, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 0, 0, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 0, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 0, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 1, 0, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 0, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 1, 0, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 0, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 0, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 2, 0, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 0, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 3, 0, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 0, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 0, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 3, 0, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 0, 1, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 1, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 0, 1, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 1, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 1, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 1, 1, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 1, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 1, 1, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 1, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 1, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 2, 1, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 1, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 3, 1, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 1, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 1, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 3, 1, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 0, 2, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 2, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 0, 2, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 2, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 2, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 1, 2, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 2, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 1, 2, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 2, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 2, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 2, 2, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 2, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 3, 2, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 2, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 2, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 3, 2, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 0, 3, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 3, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 0, 3, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 3, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 3, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 1, 3, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 3, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 1, 3, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 3, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 3, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 2, 3, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 3, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 3, 3, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 3, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 3, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 3, 3, 3, 0]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 0, 0, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 0, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 0, 0, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 0, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 0, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 1, 0, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 0, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 1, 0, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 0, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 0, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 2, 0, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 0, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 3, 0, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 0, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 0, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 3, 0, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 0, 1, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 1, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00063
# q_t的集合：[2, 0, 1, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 1, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 1, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 1, 1, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 1, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 1, 1, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 1, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 1, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00045
# q_t的集合：[2, 2, 1, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 1, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00101
# q_t的集合：[0, 3, 1, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 1, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 1, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 3, 1, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 0, 2, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 2, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 0, 2, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 2, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 2, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 1, 2, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 2, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 1, 2, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 2, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 2, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 2, 2, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 2, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 3, 2, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 2, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 2, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 3, 2, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 0, 3, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 3, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 0, 3, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 3, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 3, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 1, 3, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 3, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 1, 3, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 3, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 3, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 2, 3, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 3, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 3, 3, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 3, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 3, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 3, 3, 0, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 0, 0, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 0, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 0, 0, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 0, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 0, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 1, 0, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 0, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 1, 0, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 0, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 0, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 2, 0, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 0, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 3, 0, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 0, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 0, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 3, 0, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 0, 1, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 1, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 0, 1, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 1, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 1, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 1, 1, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 1, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 1, 1, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 1, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 1, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 2, 1, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 1, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 3, 1, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 1, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 1, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 3, 1, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 0, 2, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 2, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 0, 2, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 2, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 2, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 1, 2, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 2, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 1, 2, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 2, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 2, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 2, 2, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 2, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 3, 2, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 2, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 2, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 3, 2, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 0, 3, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 3, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 0, 3, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 3, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 3, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 1, 3, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 3, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 1, 3, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 3, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 3, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 2, 3, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 3, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 3, 3, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 3, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 3, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 3, 3, 1, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 0, 0, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 0, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 0, 0, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 0, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 0, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 1, 0, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 0, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 1, 0, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 0, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 0, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 2, 0, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 0, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 3, 0, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 0, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 0, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 3, 0, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 0, 1, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 1, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00030
# q_t的集合：[2, 0, 1, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 1, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 1, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 1, 1, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 1, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 1, 1, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 1, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 1, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00022
# q_t的集合：[2, 2, 1, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 1, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00048
# q_t的集合：[0, 3, 1, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 1, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 1, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 3, 1, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 0, 2, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 2, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 0, 2, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 2, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 2, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 1, 2, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 2, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 1, 2, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 2, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 2, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 2, 2, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 2, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 3, 2, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 2, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 2, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 3, 2, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 0, 3, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 3, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 0, 3, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 3, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 3, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 1, 3, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 3, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 1, 3, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 3, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 3, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00008
# q_t的集合：[2, 2, 3, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 3, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00017
# q_t的集合：[0, 3, 3, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 3, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 3, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00017
# q_t的集合：[3, 3, 3, 2, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00019
# q_t的集合：[0, 0, 0, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 0, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 0, 0, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 0, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 0, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 1, 0, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 0, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 1, 0, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 0, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 0, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 2, 0, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 0, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 3, 0, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 0, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 0, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 3, 0, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 0, 1, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 1, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 0, 1, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 1, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 1, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 1, 1, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 1, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 1, 1, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 1, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 1, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 2, 1, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 1, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 3, 1, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 1, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 1, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 3, 1, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 0, 2, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 2, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 0, 2, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 2, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 2, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 1, 2, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 2, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 1, 2, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 2, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 2, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 2, 2, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 2, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 3, 2, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 2, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 2, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 3, 2, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 0, 3, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 3, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 0, 3, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 3, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 3, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 1, 3, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 3, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 1, 3, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 3, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 3, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 2, 3, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 3, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 3, 3, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 3, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 3, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 3, 3, 3, 1]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 0, 0, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 0, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 0, 0, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 0, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 0, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 1, 0, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 0, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 1, 0, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 0, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 0, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 2, 0, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 0, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 3, 0, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 0, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 0, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 3, 0, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 0, 1, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 1, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 0, 1, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 1, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 1, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 1, 1, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 1, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 1, 1, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 1, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 1, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 2, 1, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 1, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 3, 1, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 1, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 1, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 3, 1, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 0, 2, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 2, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 0, 2, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 2, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 2, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 1, 2, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 2, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 1, 2, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 2, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 2, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 2, 2, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 2, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 3, 2, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 2, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 2, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 3, 2, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 0, 3, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 3, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 0, 3, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 3, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 3, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 1, 3, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 3, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 1, 3, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 3, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 3, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 2, 3, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 3, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 3, 3, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 3, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 3, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 3, 3, 0, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 0, 0, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 0, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 0, 0, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 0, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 0, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00189
# q_t的集合：[1, 1, 0, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 0, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00091
# q_t的集合：[3, 1, 0, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 0, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 0, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 2, 0, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 0, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 3, 0, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 0, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 0, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 3, 0, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 0, 1, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 1, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 0, 1, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 1, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 1, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 1, 1, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 1, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 1, 1, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 1, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 1, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 2, 1, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 1, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 3, 1, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 1, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 1, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 3, 1, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 0, 2, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 2, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 0, 2, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 2, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 2, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00091
# q_t的集合：[1, 1, 2, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 2, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00044
# q_t的集合：[3, 1, 2, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 2, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 2, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 2, 2, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 2, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 3, 2, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 2, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 2, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00145
# q_t的集合：[3, 3, 2, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00161
# q_t的集合：[0, 0, 3, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 3, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 0, 3, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 3, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 3, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 1, 3, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 3, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 1, 3, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 3, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 3, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 2, 3, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 3, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 3, 3, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 3, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 3, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 3, 3, 1, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 0, 0, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 0, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 0, 0, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 0, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 0, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 1, 0, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 0, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 1, 0, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 0, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 0, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 2, 0, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 0, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 3, 0, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 0, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 0, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 3, 0, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 0, 1, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 1, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 0, 1, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 1, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 1, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 1, 1, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 1, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 1, 1, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 1, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 1, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 2, 1, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 1, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 3, 1, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 1, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 1, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 3, 1, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 0, 2, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 2, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 0, 2, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 2, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 2, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 1, 2, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 2, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 1, 2, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 2, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 2, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 2, 2, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 2, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 3, 2, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 2, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 2, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 3, 2, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 0, 3, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 3, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 0, 3, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 3, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 3, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 1, 3, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 3, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 1, 3, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 3, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 3, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 2, 3, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 3, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 3, 3, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 3, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 3, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 3, 3, 2, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 0, 0, 3, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 0, 3, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 0, 0, 3, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 0, 3, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 0, 3, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 1, 0, 3, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 0, 3, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 1, 0, 3, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 0, 3, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 0, 3, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 2, 0, 3, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 0, 3, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 3, 0, 3, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 0, 3, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 0, 3, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 3, 0, 3, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 0, 1, 3, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 1, 3, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 0, 1, 3, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 1, 3, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 1, 3, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 1, 1, 3, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 1, 3, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 1, 1, 3, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 1, 3, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 1, 3, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 2, 1, 3, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 1, 3, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 3, 1, 3, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 1, 3, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 1, 3, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 3, 1, 3, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 0, 2, 3, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 2, 3, 2]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# ...
# q_t的集合：[3, 2, 0, 0, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 3, 0, 0, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 0, 0, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 0, 0, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 3, 0, 0, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 0, 1, 0, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 1, 0, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 0, 1, 0, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 1, 0, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 1, 0, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 1, 1, 0, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 1, 0, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 1, 1, 0, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 1, 0, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 1, 0, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 2, 1, 0, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 1, 0, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 3, 1, 0, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 1, 0, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 1, 0, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 3, 1, 0, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 0, 2, 0, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 2, 0, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 0, 2, 0, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 2, 0, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 2, 0, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 1, 2, 0, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 2, 0, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 1, 2, 0, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 2, 0, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 2, 0, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 2, 2, 0, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 2, 0, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 3, 2, 0, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 2, 0, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 2, 0, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 3, 2, 0, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 0, 3, 0, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 3, 0, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 0, 3, 0, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 3, 0, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 3, 0, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 1, 3, 0, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 3, 0, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 1, 3, 0, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 3, 0, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 3, 0, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 2, 3, 0, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 3, 0, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 3, 3, 0, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 3, 0, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 3, 0, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 3, 3, 0, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 0, 0, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 0, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 0, 0, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 0, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 0, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 1, 0, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 0, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 1, 0, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 0, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 0, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 2, 0, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 0, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 3, 0, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 0, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 0, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 3, 0, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 0, 1, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 1, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 0, 1, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 1, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 1, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 1, 1, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 1, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 1, 1, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 1, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 1, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 2, 1, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 1, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 3, 1, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 1, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 1, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 3, 1, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 0, 2, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 2, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 0, 2, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 2, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 2, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 1, 2, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 2, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 1, 2, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 2, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 2, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 2, 2, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 2, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 3, 2, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 2, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 2, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 3, 2, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 0, 3, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 3, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 0, 3, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 3, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 3, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 1, 3, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 3, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 1, 3, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 3, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 3, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 2, 3, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 3, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 3, 3, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 3, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 3, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 3, 3, 1, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 0, 0, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 0, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 0, 0, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 0, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 0, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 1, 0, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 0, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 1, 0, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 0, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 0, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 2, 0, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 0, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 3, 0, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 0, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 0, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 3, 0, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 0, 1, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 1, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00121
# q_t的集合：[2, 0, 1, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 1, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 1, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 1, 1, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 1, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 1, 1, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 1, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 1, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00087
# q_t的集合：[2, 2, 1, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 1, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00194
# q_t的集合：[0, 3, 1, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 1, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 1, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 3, 1, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 0, 2, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 2, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 0, 2, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 2, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 2, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 1, 2, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 2, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 1, 2, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 2, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 2, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 2, 2, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 2, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 3, 2, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 2, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 2, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 3, 2, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 0, 3, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 3, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 0, 3, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 3, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 3, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 1, 3, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 3, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 1, 3, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 3, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 3, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00031
# q_t的集合：[2, 2, 3, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 3, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00069
# q_t的集合：[0, 3, 3, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 3, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 3, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00069
# q_t的集合：[3, 3, 3, 2, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00077
# q_t的集合：[0, 0, 0, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 0, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 0, 0, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 0, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 0, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 1, 0, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 0, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 1, 0, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 0, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 0, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 2, 0, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 0, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 3, 0, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 0, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 0, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 3, 0, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 0, 1, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 1, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 0, 1, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 1, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 1, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 1, 1, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 1, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 1, 1, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 1, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 1, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 2, 1, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 1, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 3, 1, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 1, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 1, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 3, 1, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 0, 2, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 2, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 0, 2, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 2, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 2, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00043
# q_t的集合：[1, 1, 2, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 2, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00021
# q_t的集合：[3, 1, 2, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 2, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 2, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 2, 2, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 2, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 3, 2, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 2, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 2, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00069
# q_t的集合：[3, 3, 2, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00077
# q_t的集合：[0, 0, 3, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 0, 3, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 0, 3, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 0, 3, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 1, 3, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 1, 3, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 1, 3, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 1, 3, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[0, 2, 3, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 2, 3, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00013
# q_t的集合：[2, 2, 3, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[3, 2, 3, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00029
# q_t的集合：[0, 3, 3, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[1, 3, 3, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00000
# q_t的集合：[2, 3, 3, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00029
# q_t的集合：[3, 3, 3, 3, 3]。i0->i1  i1->i2  i2->i3  i3->i4    0.00032
# 0.026862016000000002
